# %% [markdown]
# # Eigenvalue dan Eigenvektor
#
# 1. definisi eigenvalue dan eigenvektor
#
# Eigen
# megunakan persamaan :
# $A v = λ v$
#
# $A$ = Matriks transformasi
# $V$ = eigenvektor
# $λ$ = eigen velue
#
# artinya: Ketika matriks $A$ mengalikan vektor $V$ hasilnya adalah vektor $V$ itu sendiri yang dikalikan suatu skalar $λ$. Jadi, arah vektornya tidak berubah, hanya skalanya yang berubah.
#
# ## Definisi Eigenvalue dan Eigenvector
#
# Untuk sebuah matriks kuadrat \( A \), sebuah *eigenvalue* \( \lambda \) dan *eigenvector* \( \vec{v} \) memenuhi:
#
# \[
# A\vec{v} = \lambda \vec{v}
# \]
#
# dengan syarat:
#
# - \( \vec{v} \ne \vec{0} \) (vektor tak nol)
# - \( \lambda \in \mathbb{R} \) atau \( \mathbb{C} \)
# - \( A \in \mathbb{R}^{n \times n} \) atau \( \mathbb{C}^{n \times n} \)
#
# ### Interpretasi Geometris:
# Vektor \( \vec{v} \) tidak berubah arah ketika dikalikan dengan matriks \( A \), hanya panjang dan arahnya yang bisa berubah (karena \( \lambda \)).
#
# 2. mencari eigen value dan eigen vektor dengan polinomial
#
#
# 3. urutkan dari besar ke kecil
