# %% [markdown]
# # perkalian titik (dot product)
# ## 1. a. Materi dot product
# ##    b. buat program untuk menghitung dot product vector (perkalian titik dari 2 vector)
#
# ## 2. a. materi vector satuan
# ##    b. buat program untuk mengkonversi vector menjadi vector satuan (vector memiliki panjang vector 1)
#
# hasil uploud ke web statis
